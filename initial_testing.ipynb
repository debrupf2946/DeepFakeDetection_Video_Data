# %%
import pandas as pd
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread('/Volumes/Quantiphy_ssd/Celeb Image Dataset/train/fake_id0_id1_0002_frame174.png')

# %%
img.shape
# Out:
# (299, 299, 3)

# %%
plt.imshow(img)

# %%
plt.hist(img2.ravel(),256,[0,256]);plt.show()

# %%
plt.hist(img.ravel(),256,[0,256]);plt.show()

# %%
img2 = cv.imread('/Volumes/Quantiphy_ssd/Celeb Image Dataset/train/fake_id0_id1_0003_frame264.png')

# %%
plt.imshow(img2)

# %%
img3 = cv.imread('/Volumes/Quantiphy_ssd/Celeb Image Dataset/train/real_id61_0008_frame240.png')
plt.imshow(img3)

# %%
plt.hist(img3.ravel(),256,[0,256]);plt.show()

# %%
import cv2

# %%
from components.preprocessing.pixel_distrubution_based_kfs import sample_key_frames
from models.gru_based import get_model
import keras


key_frames=sample_key_frames("data/Random/aagfhgtpmv.mp4")

# %%
type(key_frames)
# Out:
# list

# %%
len(key_frames)
# Out:
# 28

# %%
key_frames[0].shape
# Out:
# (1080, 1920, 3)

# %%
type(key_frames[0])
# Out:
# numpy.ndarray

# %%
resized_image = cv2.resize(key_frames[0], (299, 299))

# %%
resized_image.shape
# Out:
# (299, 299, 3)

# %%
type(resized_image)
# Out:
# numpy.ndarray

# %%
model=get_model()

model.load_weights("artifacts/deep_fake_GRU.weights.h5")

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
resized_image = cv2.resize(key_frames[0], (299, 299))

# %%
resized_image.shape
# Out:
# (299, 299, 3)

# %%
import numpy as np 
input_image = np.expand_dims(resized_image, axis=0)
input_image.shape
# Out:
# (1, 299, 299, 3)

# %%
predictions = model.predict(input_image)
# Out:
# /Users/debruppaul/DEEP_FAKE_JU/env/lib/python3.11/site-packages/keras/src/models/functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['keras_tensor']. Received: the structure of inputs=*
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
predictions
# Out:
# array([[0.99997395]], dtype=float32)
